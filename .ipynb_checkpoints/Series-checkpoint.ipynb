# %%
import pandas as pd

# Create a dictionary (data)
data = {
    "Name": ["Vidushi", "Aman", "Riya", "Karan"],
    "Age": [21, 22, 20, 23],
    "Marks": [85, 90, 78, 88]
}

# Convert dictionary into DataFrame
df = pd.DataFrame(data)

# Print full DataFrame
print("Full DataFrame:")
print(df)
# Out:
# Full DataFrame:
#       Name  Age  Marks
# 0  Vidushi   21     85
# 1     Aman   22     90
# 2     Riya   20     78
# 3    Karan   23     88
